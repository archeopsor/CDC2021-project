# %%
# MODULE IMPORTS
# pip install modules in requirements.txt first
import pandas as pd

# %%
# DATA
df = pd.read_excel("aspe-uninsured-estimates-by-county.xlsx")

# %%
# EDA
all_uninsured.head(5)
# Out:
#    State Name  Total Non-Elderly Population (Excluding Undocumented)  \
# 0     Alabama                                            3986500
# 1      Alaska                                             629300
# 2     Arizona                                            5720700
# 3    Arkansas                                            2443900
# 4  California                                           32060700
#
#    Uninsured Population (Excluding Undocumented)  Percent Uninsured  \
# 0                                         456100               0.11
# 1                                          80300               0.13
# 2                                         698800               0.12
# 3                                         257200               0.11
# 4                                        2397600               0.07
#
#    HIU Income < 100% FPL  HIU Income 100-138% FPL  HIU Income 139-249% FPL  \
# 0                 213000                    48800                    94700
# ...
